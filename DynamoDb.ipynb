# %% [markdown]
# <a href="https://colab.research.google.com/github/meryemCH/dynamodb/blob/main/DynamoDb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd 
df = pd.read_csv('/content/drive/MyDrive/cvsFile/Copie de FullData_2021-06-18_00-36.csv')

# %%
df
# Out:
#     Unnamed: 0                   0  ...                   12                  13
# 0            0          Ref. Enreg  ...  Prix/m2 surf.carrez  Prix/m2 surf.utile
# 1            1  9304P01 2020P01315  ...              6800,79             7058,82
# 2            2  B214P01 2020P00859  ...             13654,33            10857,14
# 3            3  B214P12 2020P00311  ...              1360741            13055,56
# 4            4  B214P01 2020P00493  ...              1276596            11538,46
# 5            5  B214P02 2020P00755  ...             13966,71            10886,49
# 6            6  B214P03 2020P00789  ...               326770             9076,94
# 7            7  B214P03 2020P00293  ...              9857,82             8432,43
# 8            8  B214P04 2020P01100  ...             10790,57            10805,56
# 9            9  B214P04 2020P00822  ...              9127,47             7466,78
# 10          10  B214P04 2020P01189  ...              8042,90              833333
# ...

# %%
import uuid

# %%
#add key for db
df.insert(loc=0, column='uuid', value=[uuid.uuid4() for _ in range(len(df.index))])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-1ee6e6a4d766> in <module>()
#       1 #add key for db
# ----> 2 df.insert(loc=0, column='uuid', value=[uuid.uuid4() for _ in range(len(df.index))])
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3626         self._ensure_valid_index(value)
#    3627         value = self._sanitize_column(column, value, broadcast=False)
# -> 3628         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3629
#    3630     def assign(self, **kwargs) -> "DataFrame":
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1184         if not allow_duplicates and item in self.items:
#    1185             # Should this be a different kind of error??
# ...

# %%
df
# Out:
#                                       Id  ...                  13
# 0   8f1781d9-9036-4a31-8b8f-ee2a744ad89a  ...  Prix/m2 surf.utile
# 1   4ef7dbb8-cda3-4eaf-93da-1c8d4a679038  ...             7058,82
# 2   8bfa4435-08d6-4e82-a0ac-c7e15a48a317  ...            10857,14
# 3   30e0f012-d59e-4931-b364-a24898d01495  ...            13055,56
# 4   dc99b867-6a9d-4fe4-b05f-27d1d2f9dc76  ...            11538,46
# 5   c4e64152-33de-4df3-b308-e92aae480221  ...            10886,49
# 6   ae5499e2-be26-4bc7-b1c5-e09e718cf8de  ...             9076,94
# 7   e7467749-2031-4508-bcaa-3ff338a3a499  ...             8432,43
# 8   fb26ab44-6a3b-4e63-a93a-abb58caaa207  ...            10805,56
# 9   457c5ccc-ba27-4baf-a6be-feadbe39f7ef  ...             7466,78
# 10  2cd88aaa-be6b-4572-a20a-8ead421ef1d2  ...              833333
# 11  d189ed7b-cbc2-4d94-aa06-5b924af6c395  ...              886842
# 12  0196db88-23f4-4b84-b764-0888dbf049a0  ...             1148148
# ...

# %%
from google.colab import drive
drive.mount('drive')
# Out:
# Drive already mounted at drive; to attempt to forcibly remount, call drive.mount("drive", force_remount=True).

# %%
df.to_csv('data.csv')
# !cp data.csv "drive/My Drive/"
